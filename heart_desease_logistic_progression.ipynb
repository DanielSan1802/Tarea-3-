# %% [markdown]
# # Modelo de regresión logística para enfermedades del corazón

# %% [markdown]
# ## 1. Cargar el Dataset y Realizar el Análisis

# %%
# Importar las librerias necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, roc_auc_score
from sklearn.preprocessing import StandardScaler

# Cargar el dataset
df = pd.read_csv('C:/Dataset/heart_cleveland_upload.csv')

# Mostrar las primeras filas del dataset
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   69    1   0       160   234    1        2      131      0      0.1      1
# 1   69    0   0       140   239    0        0      151      0      1.8      0
# 2   66    0   0       150   226    0        0      114      0      2.6      2
# 3   65    1   0       138   282    1        2      174      0      1.4      1
# 4   64    1   0       110   211    0        2      144      1      1.8      1
#
#    ca  thal  condition
# 0   1     0          0
# 1   2     0          0
# 2   0     0          0
# 3   1     0          1
# 4   0     0          0

# %% [markdown]
# ## 2. Análisis exploratorio de los datos

# %%
# Importar las librerias necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, roc_auc_score
from sklearn.preprocessing import StandardScaler

# Cargar el dataset
# Fix: Use raw string (r prefix) or double backslashes or forward slashes for file paths
df = pd.read_csv(r'C:/Dataset/heart_cleveland_upload.csv')
# Alternative options:
# df = pd.read_csv('C:\\Users\\danie\\trabajo tarea 3\\heart_deseases')
# df = pd.read_csv('C:/Users/danie/trabajo tarea 3/heart_deseases')

# Mostrar las primeras filas del dataset
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   69    1   0       160   234    1        2      131      0      0.1      1
# 1   69    0   0       140   239    0        0      151      0      1.8      0
# 2   66    0   0       150   226    0        0      114      0      2.6      2
# 3   65    1   0       138   282    1        2      174      0      1.4      1
# 4   64    1   0       110   211    0        2      144      1      1.8      1
#
#    ca  thal  condition
# 0   1     0          0
# 1   2     0          0
# 2   0     0          0
# 3   1     0          1
# 4   0     0          0

# %%
# Assistant
# Importar las librerias necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, roc_auc_score
from sklearn.preprocessing import StandardScaler

# Cargar el dataset
# Fixed: Added .csv extension to the filename and using raw string for the path
df = pd.read_csv(r'C:/Dataset/heart_cleveland_upload.csv')
# Alternative options:
# df = pd.read_csv('C:\\Users\\danie\\trabajo tarea 3\\heart_deseases.csv')
# df = pd.read_csv('C:/Users/danie/trabajo tarea 3/heart_deseases.csv')

# Mostrar las primeras filas del dataset
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   69    1   0       160   234    1        2      131      0      0.1      1
# 1   69    0   0       140   239    0        0      151      0      1.8      0
# 2   66    0   0       150   226    0        0      114      0      2.6      2
# 3   65    1   0       138   282    1        2      174      0      1.4      1
# 4   64    1   0       110   211    0        2      144      1      1.8      1
#
#    ca  thal  condition
# 0   1     0          0
# 1   2     0          0
# 2   0     0          0
# 3   1     0          1
# 4   0     0          0

# %%
# Importar las librerias necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, roc_auc_score
from sklearn.preprocessing import StandardScaler

# Cargar el dataset
# Opción 1: Especificar la ruta completa al archivo
df = pd.read_csv('C:/Dataset/heart_cleveland_upload.csv')  # Reemplaza con la ruta correcta

# Opción 2: Si estás en Google Colab, puedes subir el archivo
# from google.colab import files
# uploaded = files.upload()  # Esto abrirá un cuadro de diálogo para subir el archivo
# df = pd.read_csv('heart_cleveland_upload.csv')

# Opción 3: Descargar el dataset directamente si está disponible en línea
# url = "https://ejemplo.com/heart_cleveland_upload.csv"  # Reemplaza con la URL correcta
# df = pd.read_csv(url)

# Mostrar las primeras filas del dataset
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   69    1   0       160   234    1        2      131      0      0.1      1
# 1   69    0   0       140   239    0        0      151      0      1.8      0
# 2   66    0   0       150   226    0        0      114      0      2.6      2
# 3   65    1   0       138   282    1        2      174      0      1.4      1
# 4   64    1   0       110   211    0        2      144      1      1.8      1
#
#    ca  thal  condition
# 0   1     0          0
# 1   2     0          0
# 2   0     0          0
# 3   1     0          1
# 4   0     0          0

# %%
# Descripcion estadistica del dataset
df.describe()

# Visualizar la correlacion entre variables
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()

# Identificar valores atipicos
sns.boxplot(data=df)
plt.show()

# %%
# Importar las librerias necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, roc_auc_score
from sklearn.preprocessing import StandardScaler

# Cargar el dataset
# Fixed: Added .csv extension to the filename and using raw string for the path
df = pd.read_csv(r'C:/Dataset/heart_cleveland_upload.csv')
# Alternative options:
# df = pd.read_csv('C:\\Users\\danie\\trabajo tarea 3\\heart_deseases.csv')
# df = pd.read_csv('C:/Users/danie/trabajo tarea 3/heart_deseases.csv')

# Mostrar las primeras filas del dataset
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   69    1   0       160   234    1        2      131      0      0.1      1
# 1   69    0   0       140   239    0        0      151      0      1.8      0
# 2   66    0   0       150   226    0        0      114      0      2.6      2
# 3   65    1   0       138   282    1        2      174      0      1.4      1
# 4   64    1   0       110   211    0        2      144      1      1.8      1
#
#    ca  thal  condition
# 0   1     0          0
# 1   2     0          0
# 2   0     0          0
# 3   1     0          1
# 4   0     0          0

# %% [markdown]
# ## 3. Pre procesamiento de los datos

# %%
# Limpiar datos faltantes
df = df.dropna()

# Seleccionar las caracteristicas mas relevantes
X = df[['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal']]
y = df['condition']

# Escalar las caracteristicas
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## 4. Dividir el Dataset en Train y Test

# %%
# Dividir el dataset en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## 5. Entrenar el modelo

# %%
# Definir el modelo de regresion logistica
model = LogisticRegression()

# Definir el espacio de busqueda de hiperparametros
param_grid = {
    'C': [0.1, 1.0, 10.0, 100.0],
    'solver': ['liblinear', 'saga']
}

# Utilizar GridSearchCV para encontrar los mejores hiperparametros
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)

# Obtener los mejores hiperparametros
best_params = grid_search.best_params_
print(f'Mejores hiperparametros: {best_params}')

# Entrenar el modelo con los mejores hiperparametros
best_model = LogisticRegression(C=best_params['C'], solver=best_params['solver'])
best_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# Mejores hiperparametros: {'C': 0.1, 'solver': 'liblinear'}
# LogisticRegression(C=0.1, solver='liblinear')

# %% [markdown]
# ## 6. Evaluar el desempeño del modelo

# %%
# Realizar predicciones
y_pred = best_model.predict(X_test)

# Calcular metricas de evaluacion
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
print(f'ROC AUC Score: {roc_auc}')
# Out:
# Accuracy: 0.84
# Precision: 0.8918918918918919
# Recall: 0.8048780487804879
# F1 Score: 0.8461538461538461
# ROC AUC Score: 0.8436154949784792

# %% [markdown]
# ## 7. Visualizar los resultados

# %%
# Graficar la matriz de confusion
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Graficar la curva ROC
fpr, tpr, _ = roc_curve(y_test, best_model.predict_proba(X_test)[:, 1])
plt.plot(fpr, tpr, marker='.')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %% [markdown]
# ## 8. Interpretación de los resultados

# %% [markdown]
# ### Interpretacion de Resultados
#
# - **Accuracy**: Proporción de predicciones correctas sobre el total de predicciones.
# - **Precision**: Proporción de verdaderos positivos sobre el total de predicciones positivas.
# - **Recall**: Proporción de verdaderos positivos sobre el total de verdaderos positivos y falsos negativos.
# - **F1 Score**: Media armónica de la precisión y el recall.
# - **ROC AUC Score**: Área bajo la curva ROC, que mide la capacidad del modelo para distinguir entre clases.
#
# ### Conclusiones
#
# - El modelo de regresion logistica muestra un buen rendimiento con una precisión de 0.6875, un recall de 0.7857142857142857, y un F1 Score de 0.7333333333333334.
